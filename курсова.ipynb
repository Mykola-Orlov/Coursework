# %% [markdown]
# ![image.png](attachment:image.png)
#
# <center><span style="font-size:20px;">Міністерство освіти і науки, молоді та спорту
# України Національний технічний університет
# України "Київський політехнічний інститут імені
# Ігоря Сікорського" Фізико - технічний інститут</span></center><br/>
#
# <center><b style="font-size: 200%;"> Курсова робота</b></center>
#
# <center><b style="font-size: 200%;"> Аналіз даних за допомогою Python та бібліотеки Pandas </b></center><br/><br/><br/><br/>
#
# **Виконав**:
# Студент групи ФІ-21 Орлов Микола, НН ФТІ  <br/> **Перевірив**

# %% [markdown]
# <center><b style="font-size: 200%;"> ЧАСТИНА 1</b></center><br/>
#
# <span style="font-size:20px;">**Мета**: Вивчення основних принципів роботи та використання програмних
# компонентів Anaconda. Інсталяція. Дослідження можливостей IPython Notebook.</span>
#
# <center><b style="font-size: 200%;"> Вступ</b></center><br/>
#
# <span style="font-size:20px;">**Ipython Notebook** — це середовище розробки, що дає можливості для
# інтерактивної та ітеративної розробки проектів, пов’язаних з Data Science.
# Notebook інтегрує код та результати його виконання в один файл разом з
# графіками, текстом, математичними виразами та іншими можливими видами
# представлення інформації.</span><br/>
#
# <span style="font-size:20px;">**Jupyter Notebook** – неймовірно потужний інструмент для інтерактивної розробки
# та подання проектів в області наук про дані. Це зручний інструмент для створення
# аналітичних звітів, що дозволяє одночасно зберігати разом код, формули,
# зображення, коментарі, результати і графіки.
# Блокнот (notebook) представляє код і результат його виведення в єдиному
# документі, який об’єднує візуалізацію, розмічений текст, математичні рівняння та
# інші мультимедійні дані. Цей інтуїтивно зрозумілий робочий процес сприяє
# ітеративній і швидкій розробці, що робить ноутбуки все більш популярним
# вибором для подання даних і їх аналізу. Notebook інтегрує код та результати його
# виконання в один файл разом з графіками, текстом, математичними виразами та
# іншими можливими видами представлення інформації.</span><br/>
#
# <span style="font-size:20px;">**Anaconda** — це вільно та відкрито розповсюджуваний дистрибутив різних програмних продуктів, зокрема, мов програмування Python та R(мова програмуавння). Платформа спеціалізується на «наукових обчисленнях»: наука про дані, застосуванні методів машинного навчання, широкомасштабна обробка даних, передбачувальна аналітика тощо. Використання платформи має на меті спрощення управління пакетами та їх розгортання. Дистрибутив Anaconda використовується понад 15 мільйонами користувачів і містить більше 1500 популярних пакетів наукових даних, придатних для Windows, Linux та MacOS, наприклад, NumPy, SciPy та Ggplot2.</span>

# %% [markdown]
# # Інсталяція
# 1. З сайту https://www.anaconda.com/products/distribution завантажте Anaconda
# Distribution:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Після завантаження запускаємо Anaconda Navigator:
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Натискаємо «Install» під Jupyter Notebook. Так як у мене вже інстальовано, то присутня кнопка «Launch»
# ![image.png](attachment:image.png)

# %% [markdown]
# Після завантаженні ми вже можемо працювати в Jupyter Notebook.
# Також доцільно буде створити Jupyter Notebook одразу в віртуальному середовищі.
# Для цього потрібно нажати
# ![image.png](attachment:image.png)
# Далі натискаєтемо «Create»
# ![image-2.png](attachment:image-2.png)
# Після створення можемо відкривати Jupyter Notebook(назва віртуального серидовища якого ви створили)
# Та вже працюємо в ньому

# %% [markdown]
# # Можливості Jupyter Notebook
# - Редагувати Python код в браузері, з підсвічуванням синтаксису,
# автовідступами і автодоповненням;
# - Запускати код в браузері;
# - Відображати результати обчислень з медіа представленням(схеми, графіки);
# - Працювати з мовою розмітки Markdown і LaTeX.

# %% [markdown]
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# # ЧАСТИНА 2
# **Мета**: Отримати досвід використання основних засобів аналізу та візуалізації
# даних у середовищі IPython Notebook на модельних наборах даних.
#
# В роботі використовується публічний набір даних "Cancer Data" - https://www.kaggle.com/datasets/erdemtaha/cancer-data.
# Імпортуємо необхідні бібліотеки та відкриваємо набір даних методами pandas

# %%
# імпортуємо бібліотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys

# %%
#Установлюємо стиль оформлення діаграм
sns.set(style="darkgrid")

# %%
#завантажуємо набір даних
df = pd.read_csv('C:\\Users\\орлов ілля\\OneDrive\\Робочий стіл\\Anaconda\\курсач\\dataset\\Cancer_Data.csv')
csv_path = 'C:\\Users\\орлов ілля\\OneDrive\\Робочий стіл\\Anaconda\\курсач\\dataset\\Cancer_Data.csv'

# %%
#виводимо перші 5 рядків(якщо в дужках вказати цифру n, виведеться n-на кількість рядків)
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# # Завдання 2
# Проаналізувати набір даних на наявність пропущених значень та NaN.<br/>
# У випадку наявності таких значень їх потрібно заповнити значеннями за допомогою fillna,
# використовуючи метод bfill (заміна на наступне валідне значення після Nan) або ffil (заміна
# на попереднє валідне значення після Nan)

# %%
#аналізуємо набір даних на наявність пропущених значень та NaN
df.isnull().values.any()
# Out:
# True

# %%
#заповнюємо значеннями за допомогою fillna,використовуючи метод ffill(заміна на попереднє валідне значення після Nan)
df.fillna(method='ffill')
# Out:
# C:\Users\орлов ілля\AppData\Local\Temp\ipykernel_50636\823208606.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# ...

# %% [markdown]
# Повідомлення про попередження вказує на те, що використання параметра method у функції fillna для заповнення пропущених значень у DataFrame застаріле і може бути вилучено у майбутніх версіях бібліотеки pandas.
# Замість використання fillna(method='ffill'), нам рекомендують використовувати методи ffill() або bfill()

# %%
#заповнюємо значеннями за допомогою fillna
df1 = df.fillna(0)
df1.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Зчитуємо дані з CSV-файлу
data = pd.read_csv('C:\\Users\\орлов ілля\\OneDrive\\Робочий стіл\\Anaconda\\курсач\\dataset\\Cancer_Data.csv')

# Вибираємо всі стовпці, крім останнього
data_except_last_column = data.iloc[:, :-1]

# Виводимо результати
print("DataFrame з усіма стовпцями крім останнього:")
print(data_except_last_column)
# Out:
# DataFrame з усіма стовпцями крім останнього:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# ...

# %% [markdown]
# ## Завдання 3
# Відкрити набір даних засобами pandas.

# %%
# Зчитування даних з CSV-файлу
df = pd.read_csv(csv_path)

# %% [markdown]
# ## Завдання 4
# Відобразити 10 елементів для 4-ох ознак Виділити
# зеленим кольором максимальні елементи в таблиці, а червоним мінімальні для цих 10-ти
# елементів.

# %%
# Зчитування значень з файлу CSV
data = pd.read_csv('C:\\Users\\орлов ілля\\OneDrive\\Робочий стіл\\Anaconda\\курсач\\dataset\\Cancer_Data.csv')

# Вибір стовпців 3, 4, 5, 6 та перших 10 рядків
selected_data = data.iloc[:10, [2, 3, 4, 5]]

# Ініціалізація списків для збереження мінімальних та максимальних значень
min_vals_34 = selected_data.iloc[:, :2].min(axis=1)
max_vals_34 = selected_data.iloc[:, :2].max(axis=1)
min_vals_56 = selected_data.iloc[:, 2:].min(axis=1)
max_vals_56 = selected_data.iloc[:, 2:].max(axis=1)

# Створення карти для відображення даних
heatmap = np.zeros((10, 4, 4), dtype=float)

for i in range(10):
    for j in range(4):
        val = selected_data.iat[i, j]
        
        if j < 2:
            min_val = min_vals_34[i]
            max_val = max_vals_34[i]
        else:
            min_val = min_vals_56[i]
            max_val = max_vals_56[i]
        
        if val == min_val:
            heatmap[i, j] = [0, 1, 0, 1.0]  # Зелений колір
        elif val == max_val:
            heatmap[i, j] = [1, 0, 0, 1.0]  # Червоний колір
        else:
            heatmap[i, j] = [1, 1, 1, 0.0]  # Прозорий колір

# Встановлення більшого розміру фігури
plt.figure(figsize=(5, 15))

# Відображення даних у вигляді теплової карти
plt.imshow(heatmap)

# Додавання значень до комірок та збільшення розміру шрифту
for i in range(10):
    for j in range(4):
        val = selected_data.iat[i, j]
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=12)

# Вимкнення вісей та відображення графіка
plt.axis('off')
plt.show()

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Зчитуємо дані з CSV-файлу
data = data_except_last_column

# Вибираємо всі стовпці, починаючи з третього
data_selected = data.iloc[:, 2:]

# Обчислюємо математичне сподівання та стандартне відхилення для вибраних даних
mean_selected = data_selected.mean()
std_selected = data_selected.std()

# Дисперсія для вибраних даних
variance_selected = np.var(data_selected)

# Стандартизуємо вибрані дані
standardized_data_selected = (data_selected - mean_selected) / std_selected

# Виводимо результати
print("Математичне сподівання для вибраних даних:")
print(mean_selected)
print("Дисперсія для вибраних даних:")
print(variance_selected)
print("\nСтандартне відхилення для вибраних даних:")
print(std_selected)
print("\nСтандартизовані вибрані дані:")
standardized_data_selected.head(10)
# Out:
# C:\anaconda3\envs\env\Lib\site-packages\numpy\core\fromnumeric.py:3785: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# Математичне сподівання для вибраних даних:
# radius_mean                 14.127292
# texture_mean                19.289649
# perimeter_mean              91.969033
# area_mean                  654.889104
# smoothness_mean              0.096360
# compactness_mean             0.104341
# concavity_mean               0.088799
# concave points_mean          0.048919
# symmetry_mean                0.181162
# fractal_dimension_mean       0.062798
# radius_se                    0.405172
# texture_se                   1.216853
# perimeter_se                 2.866059
# area_se                     40.337079
# smoothness_se                0.007041
# ...

# %% [markdown]
# ## Завдання 5
# Провести візуалізацію даних. Для цього необхідно побудувати такі типи графіків: Line Plot,
# Bare Chart, Histogram, Heatmap.

# %%
#заголовок
plt.title("Графік найгіршої гладкості на компактності за діагнозами")

# Лінійна діаграма, що показує smoothness_worst за діагнозами
sns.lineplot(data=df['smoothness_worst'], label="smoothness_worst")

# Лінійна діаграма, що показує compactness_worst за діагнозами
sns.lineplot(data=df['compactness_worst'], label="compactness_worst")

# Додаю назву горизонтальної осі
plt.xlabel("diagnosis")
# Out:
# Text(0.5, 0, 'diagnosis')

# %%
#діаграма залежності area_mean від diagnosis
#розмір
plt.figure(figsize=(10,5))

#заголовок
plt.title("Залежність area_mean від diagnosis")

# Побудова стовпчикової діаграми
sns.barplot(x="diagnosis", y="area_mean", data=df)

# Додавання назви вертикальної осі
plt.ylabel("area_mean")

# Показ графіку
plt.show()

# %%
# Вибірка 20 стовпців та 20 рядків, вилучаючи перші два стовпці,бо 1 стовпець це id а другий типу float
subset = df.iloc[2:22, 2:22]

# Встановлюю розмір графіка
plt.figure(figsize=(20, 10))

# Заголовок
plt.title("Теплова карта для вибірки 20x20")

# Побудова теплової карти
sns.heatmap(data=subset, annot=True, cmap="YlGnBu")

# Додавання назв осей за потреби
plt.xlabel("Columns")
plt.ylabel("Rows")

plt.show()

# %% [markdown]
# Так як я обрав не дуже влучний датасет де значення в двух колонках перевищують усі інші значення в 10 разів, то heatmap мене не влаштовує. Тому я видаляю з вибірки ці дві колонки і спочатку роблю вивів без цих колонок а потім окремо ці 2 колонки

# %%
# Вибірка 20 рядків та всіх стовпців, вилучаючи перші два та стовпці area_mean та perimeter_mean
subset_without_selected_columns = df.iloc[2:22, 2:22].drop(columns=["area_mean", "perimeter_mean"])

# Встановлюємо розмір графіка
plt.figure(figsize=(20, 10))

# Заголовок
plt.title("Теплова карта для вибірки 20x20 без стовпців area_mean та perimeter_mean")

# Побудова теплової карти
sns.heatmap(data=subset_without_selected_columns, annot=True, cmap="YlGnBu")

# Додавання назв осей за потреби
plt.xlabel("Columns")
plt.ylabel("Rows")

plt.show()

# %%
# Вибірка лише стовпців area_mean та perimeter_mean
subset_selected_columns = df.loc[:19, ["area_mean", "perimeter_mean"]]

# Встановлюємо розмір графіка
plt.figure(figsize=(10, 5))

# Заголовок
plt.title("Теплова карта для стовпців area_mean та perimeter_mean")

# Побудова теплової карти
sns.heatmap(data=subset_selected_columns, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Значення'})

# Додавання назв осей за потреби
plt.xlabel("Columns")
plt.ylabel("Rows")

plt.show()

# %%
#uістограмf area_mean
sns.histplot(data=df['area_mean'])
# Out:
# <Axes: xlabel='area_mean', ylabel='Count'>

# %% [markdown]
# ## Завдання 6
#
# Збудувати лінійний графік з 4-ма лініями, які взяті з ознак та додати annotate для середнього
# значення кожної лінії. При цьому для візуалізації багатовимірних даних з кількістю ознак
# більше двох обов’язково необхідно за допомогою subplot збудувати 9 графіків за
# допомогою комбінування різних ознак.

# %%
# Обираємо колонки та створюємо DataFrame
columns = ['perimeter_mean', 'area_mean', 'perimeter_worst', 'area_worst']
df3 = df[columns]

# Розмір графіка
plt.figure(figsize=(10, 5))

# Побудова лінійного графіка з чотирма лініями
for column in columns:
    sns.lineplot(data=df3[column], label=column)

# Додавання анотацій для середнього значення кожної лінії
for column in df3.columns:
    mean_value = df3[column].mean()
    plt.annotate(f'Mean: {mean_value:.2f}', xy=(df3.index[-1] + 0.1, mean_value), color='black', fontsize=10)

# Додавання заголовка та назви осі X
plt.title("Лінійний графік з анотаціями для середнього значення")
plt.xlabel("Індекс")
plt.ylabel("Значення атрибута")
plt.legend()  # Додавання легенди
plt.show()

# %%
selected_features = ['perimeter_mean', 'radius_mean', 'texture_mean', 'texture_worst']
pp = sns.pairplot(df[selected_features], hue='texture_mean')  # Створення попарних графіків розсіювання за допомогою Seaborn
plt.show()

# %% [markdown]
# ## Завдання 7
# Вирахувати коефіцієнт пірсона для кожної пари ознак.
#
# Взяти третю ознаку за вісь X та збудувати relplot для двох ознак, що мають найбільшу
# кореляцію за допомогою бібліотеки seaborn.
#
# ![image.png](attachment:image.png)

# %%
# Видалення стовпця "Unnamed: 32"
df1 = df1.drop("Unnamed: 32", axis=1, errors='ignore')

# Вибір числових стовпців (без перших двох стовпців)
numeric_columns = df1.iloc[:, 2:].select_dtypes(include=[np.number])

# Обчислення коефіцієнта кореляції Пірсона
correlation_matrix = numeric_columns.corr(method='pearson')

# Розмір графіка
plt.figure(figsize=(15, 10))

# Вивід теплової карти з анотаціями, округленими до десятків
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".1f", linewidths=.5)

# Додавання заголовка
plt.title("Теплова карта кореляції Пірсона")

plt.show()

# %%
# Визначаємо пару ознак з найбільшою кореляцією (окрім 1 та 2 стовпців)
max_correlation = 0
feature_A, feature_B = None, None

for i in range(2, len(df.columns)):                # Цикл, який перебирає індекси стовпців у фреймі даних, починаючи з індексу 2.
    for j in range(i + 1, len(df.columns)):      # Внутрішній цикл, який перебирає індекси стовпців у фреймі даних, починаючи з індексу, який є на одиницю більшим за i
        correlation = df[df.columns[i]].corr(df[df.columns[j]])  # Обчислення коефіцієнта кореляції між парою стовпців
        if abs(correlation) > max_correlation:     # Перевірка, чи модуль коефіцієнта кореляції є більшим за поточне максимальне значення.
            max_correlation = abs(correlation)     # Якщо умова вище виконується, оновлюємо max_correlation новим значенням
            feature_A, feature_B = df.columns[i], df.columns[j]  # Оновлення feature_A та feature_B іменами стовпців, які утворюють пару з максимальним або мінімальним коефіцієнтом кореляці

print(f"Найбільша кореляція (окрім 1 та 2 стовпців) між {feature_A} та {feature_B}: {max_correlation}")


# Збудовуємо relplot для цих двох ознак
sns.relplot(x=feature_A, y=feature_B, data=df)
plt.show()
# Out:
# Найбільша кореляція (окрім 1 та 2 стовпців) між radius_mean та perimeter_mean: 0.9978552814938105

# %% [markdown]
# ## Завдання 8
#
# У початковому наборі даних, перед заміною значень Nan на валідні значення за допомогою
# fillna, необхідно видалити всі колонки із значеннями Nan.

# %%
# Видалення колонок з відсутніми значеннями
df_no_missing_columns = df.dropna(axis=1, how='any')

# Заповнення відсутніх значень в залишених колонках
df_no_missing_columns_filled = df_no_missing_columns.fillna(0)
df_no_missing_columns_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# **Висновок** :
#
# Кількість рядків та колонок: DataFrame має 569 рядків та 32 колонки.
#
#
# Пропущені значення: Немає пропущених значень в жодній з колонок.
#
#
# Розподіл даних:
#
# - Кількість непустих значень для кожної колонки різна.
# - Колонки, такі як id та diagnosis, мають 569 непустих значень (non-null), що вказує на те, що для кожного рядка існують значення.
# - Решта колонок, які представляють числові ознаки (наприклад, radius_mean, texture_mean, і так далі), також мають 569 непустих значень, що свідчить про відсутність пропущених даних.
#
#
# Загальний обсяг пам'яті: DataFrame займає 142.4+ кілобайта пам'яті.

# %% [markdown]
# ## Завдання 9
#
# Видалити також випадкові значення з ознак що мають найбільшу кореляцію у кількості 10%
# для обох. Підрахувати кореляцію. Збудувати multipple scatterplot за допомогою FacetGrid
# для цих оновлених ознак використовуючи бібліотеку seaborn взявши третю ознаку за вісь x.

# %%
# Визначення пари ознак з найбільшою кореляцією (окрім 1 та 2 стовпців)
max_correlation = 0
feature_A, feature_B = None, None

for i in range(2, len(df.columns)):                # Цикл, який перебирає індекси стовпців у фреймі даних, починаючи з індексу 2.
    for j in range(i + 1, len(df.columns)):      # Внутрішній цикл, який перебирає індекси стовпців у фреймі даних, починаючи з індексу, який є на одиницю більшим за i
        correlation = df[df.columns[i]].corr(df[df.columns[j]])  # Обчислення коефіцієнта кореляції між парою стовпців
        if abs(correlation) > max_correlation:     # Перевірка, чи модуль коефіцієнта кореляції є більшим за поточне максимальне значення.
            max_correlation = abs(correlation)     # Якщо умова вище виконується, оновлюємо max_correlation новим значенням
            feature_A, feature_B = df.columns[i], df.columns[j]  # Оновлення feature_A та feature_B іменами стовпців, які утворюють пару з максимальним або мінімальним коефіцієнтом кореляці

print(f"Найбільша кореляція (окрім 1 та 2 стовпців) між {feature_A} та {feature_B}: {max_correlation}")

# Випадкове видалення 10% значень для обох ознак з найбільшою кореляцією
df_no_missing = df.copy()

for feature in [feature_A, feature_B]:   # Це цикл, який перебирає стовпці, які були знайдені з найбільшим або найменшим коефіцієнтом
    indices_to_remove = np.random.choice(df_no_missing.index, size=int(0.1 * len(df_no_missing)), replace=False) # вказує розмір (кількість) індексів, які потрібно вибрати, і в даному випадку це 10% від усіх рядків.
    df_no_missing.loc[indices_to_remove, feature] = np.nan   # Встановлення випадково обраних рядків та стовпця feature у фреймі даних 

# Підрахунок кореляції після видалення випадкових значень
correlation_after_removal = df_no_missing[feature_A].corr(df_no_missing[feature_B])
print(f"Кореляція після видалення випадкових значень: {correlation_after_removal}")

# Збудова multipple scatterplot за допомогою FacetGrid
g = sns.FacetGrid(df_no_missing, col="diagnosis", height=4, aspect=1) # aspect=1 - на співвідношення ширини та висоти.
g.map(sns.scatterplot, feature_A, feature_B, alpha=0.7) # alpha=0.7 вказує на прозорість точок
g.add_legend()

plt.show()
# Out:
# Найбільша кореляція (окрім 1 та 2 стовпців) між radius_mean та perimeter_mean: 0.9978552814938105
# Кореляція після видалення випадкових значень: 0.9978045537960332

# %% [markdown]
# <center><b style="font-size: 200%;"> ВИСНОВКИ</b></center>
#
# <span style="font-size:20px;">У ході вивчення основних принципів роботи та використання компонентів Anaconda ми ознайомились з потужним інструментарієм для роботи з даними та аналізу інформації. Використання віртуального середовища дозволяє зручно та ефективно управляти залежностями проекту та забезпечити його ізольованість.</span>
#
# <span style="font-size:20px;">Під час роботи з IPython Notebook ми вивчили основи програмування на Python, а також опанували бібліотеки Pandas, Numpy, Matplotlib, Seaborn, Plotly та Scipy для аналізу та візуалізації даних. Ці інструменти виявилися потужними та гнучкими для розв'язання різноманітних завдань у сфері аналізу даних.</span>
#
# <span style="font-size:20px;">У результаті успішно завершеної курсової роботи ми отримали не лише теоретичні знання, а й практичні навички в роботі з великим обсягом даних. Використання засобів Anaconda робить процес аналізу даних більш зручним та ефективним, дозволяючи легко обробляти, візуалізувати та інтерпретувати отримані результати.</span>

# %% [markdown]
# <center><b style="font-size: 200%;"> Посилання на джерелла</b></center>
# <a href="https://github.com/Mykola-Orlov/Coursework">Курсова</a></br>
# <a href="https://uk.wikipedia.org/wiki/Jupyter">Ipython Notebook</a></br>
# <a href="https://uk.wikipedia.org/wiki/Jupyter">Jupyter Notebook</a></br>
# <a href="https://uk.wikipedia.org/wiki/Anaconda_(%D0%B4%D0%B8%D1%81%D1%82%D1%80%D0%B8%D0%B1%D1%83%D1%82%D0%B8%D0%B2_Python)">Anaconda</a>
