# %%
#імпортуємо бібліотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys

# %%
#Установлюємо стиль оформлення діаграм
sns.set(style="darkgrid")

# %%
#завантажуємо набір даних
df = pd.read_csv('C:\\Users\\орлов ілля\\OneDrive\\Робочий стіл\\Anaconda\\курсач\\dataset\\Cancer_Data.csv')
csv_path = 'C:\\Users\\орлов ілля\\OneDrive\\Робочий стіл\\Anaconda\\курсач\\dataset\\Cancer_Data.csv'

# %%
#виводимо перші 5 рядків(якщо в дужках вказати цифру n, виведеться n-на кількість рядків)
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#аналізуємо набір даних на наявність пропущених значень та NaN
df.isnull().values.any()
# Out:
# True

# %%
#заповнюємо значеннями за допомогою fillna,використовуючи метод ffill(заміна на попереднє валідне значення після Nan)
df.fillna(method='ffill')
# Out:
# C:\Users\орлов ілля\AppData\Local\Temp\ipykernel_21920\823208606.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# ...

# %%
#заповнюємо значеннями за допомогою fillna
df1 = df.fillna(0)
df1.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = pd.read_csv(csv_path)

# %%
# Зчитування значень з файлу CSV
data = pd.read_csv('C:\\Users\\орлов ілля\\OneDrive\\Робочий стіл\\Anaconda\\курсач\\dataset\\Cancer_Data.csv')

# Вибір стовпців 3, 4, 5, 6 та перших 10 рядків
selected_data = data.iloc[:10, [2, 3, 4, 5]]

# Ініціалізація списків для збереження мінімальних та максимальних значень
min_vals_34 = selected_data.iloc[:, :2].min(axis=1)
max_vals_34 = selected_data.iloc[:, :2].max(axis=1)
min_vals_56 = selected_data.iloc[:, 2:].min(axis=1)
max_vals_56 = selected_data.iloc[:, 2:].max(axis=1)

# Створення карти для відображення даних
heatmap = np.zeros((10, 4, 4), dtype=float)

for i in range(10):
    for j in range(4):
        val = selected_data.iat[i, j]
        
        if j < 2:
            min_val = min_vals_34[i]
            max_val = max_vals_34[i]
        else:
            min_val = min_vals_56[i]
            max_val = max_vals_56[i]
        
        if val == min_val:
            heatmap[i, j] = [0, 1, 0, 1.0]  # Зелений колір
        elif val == max_val:
            heatmap[i, j] = [1, 0, 0, 1.0]  # Червоний колір
        else:
            heatmap[i, j] = [1, 1, 1, 0.0]  # Прозорий колір

# Встановлення більшого розміру фігури
plt.figure(figsize=(5, 15))

# Відображення даних у вигляді теплової карти
plt.imshow(heatmap)

# Додавання значень до комірок та збільшення розміру шрифту
for i in range(10):
    for j in range(4):
        val = selected_data.iat[i, j]
        plt.text(j, i, f'{val:.2f}', ha='center', va='center', color='black', fontsize=12)

# Вимкнення вісей та відображення графіка
plt.axis('off')
plt.show()

# %%
# Визначаємо дані, які потрібно стандартизувати 
data = np.array([1, 2, 3, 4, 5])

# Обчислюємо математичне сподівання (середнє значення)
mean = np.mean(data)

# Обчислюємо стандартне відхилення
std = np.std(data)

# Стандартизуйемо дані
standardized_data = (data - mean) / std

# Виводимо результати
print("Математичне сподівання:", mean)
print("Стандартне відхилення:", std)
print("Стандартизовані дані:", standardized_data)
# Out:
# Математичне сподівання: 3.0
# Стандартне відхилення: 1.4142135623730951
# Стандартизовані дані: [-1.41421356 -0.70710678  0.          0.70710678  1.41421356]

# %%
#розмір
plt.figure(figsize=(10,5))

#заголовок
plt.title("Графік найгіршої гладкості на компактності за діагнозами")

# Лінійна діаграма, що показує smoothness_worst за діагнозами
sns.lineplot(data=df['smoothness_worst'], label="smoothness_worst")

# Лінійна діаграма, що показує compactness_worst за діагнозами
sns.lineplot(data=df['compactness_worst'], label="compactness_worst")

# Додаю назву горизонтальної осі
plt.xlabel("diagnosis")
# Out:
# Text(0.5, 0, 'diagnosis')

# %%
#діаграма залежності area_mean від diagnosis
#розмір
plt.figure(figsize=(10,5))

#заголовок
plt.title("Залежність area_mean від diagnosis")

# Побудова стовпчикової діаграми
sns.barplot(x="diagnosis", y="area_mean", data=df)

# Додавання назви вертикальної осі
plt.ylabel("area_mean")

# Показ графіку
plt.show()

# %%
# Вибірка 20 стовпців та 20 рядків, вилучаючи перші два стовпці,бо 1 стовпець це id а другий типу float
subset = df.iloc[2:22, 2:22]

# Встановлюю розмір графіка
plt.figure(figsize=(20, 10))

# Заголовок
plt.title("Теплова карта для вибірки 20x20")

# Побудова теплової карти
sns.heatmap(data=subset, annot=True, cmap="YlGnBu")

# Додавання назв осей за потреби
plt.xlabel("Columns")
plt.ylabel("Rows")

plt.show()

# %%
#uістограмf area_mean
sns.histplot(data=df['area_mean'])
# Out:
# <Axes: xlabel='area_mean', ylabel='Count'>

# %%
# Створення DataFrame
df3 = pd.DataFrame({'perimeter_mean': [3, 4, 5, 6], 'area_mean': [5, 6, 7, 8], 'perimeter_worst': [6, 7, 8, 9], 'area_worst': [4, 5, 6, 7]})
# Розмір графіка
plt.figure(figsize=(10, 5))

# Побудова лінійного графіка з чотирма лініями та маркерами
sns.lineplot(data=df3, markers=True)

# Додавання анотацій для середнього значення кожної лінії
for column in df3.columns:
    mean_value = df3[column].mean()                                                                           # 2f відображає дві цифри після крапки.
    plt.annotate(f'Mean: {mean_value:.2f}', xy=(df3.index[-1] + 0.1, mean_value), color='black', fontsize=10) # df3.index[-1] + 0.1 - координати точки, в якій розміщується текст
                                                                                                              # fontsize - Розмір шрифту тексту
# Додавання заголовка та назви осі X
plt.title("Лінійний графік з анотаціями для середнього значення")
plt.xlabel("Індекс")
plt.show()

# %%
selected_features = ['perimeter_mean', 'radius_mean', 'texture_mean', 'texture_worst']
pp = sns.pairplot(df[selected_features], hue='texture_mean')  # Створення попарних графіків розсіювання за допомогою Seaborn
plt.show()

# %%
#виводимо перші 5 рядків(якщо в дужках вказати цифру n, виведеться n-на кількість рядків)
df1.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Вибір числових стовпців (без перших двох стовпців)
numeric_columns = df1.iloc[:, 2:].select_dtypes(include=[np.number])

# Обчислення коефіцієнта кореляції Пірсона
correlation_matrix = numeric_columns.corr(method='pearson')

# Вивід матриці кореляції
print(correlation_matrix)
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
# Визначаємо пару ознак з найбільшою кореляцією (окрім 1 та 2 стовпців)
max_correlation = 0
feature_A, feature_B = None, None

for i in range(2, len(df.columns)):                # Цикл, який перебирає індекси стовпців у фреймі даних, починаючи з індексу 2.
    for j in range(i + 1, len(df.columns)):      # Внутрішній цикл, який перебирає індекси стовпців у фреймі даних, починаючи з індексу, який є на одиницю більшим за i
        correlation = df[df.columns[i]].corr(df[df.columns[j]])  # Обчислення коефіцієнта кореляції між парою стовпців
        if abs(correlation) > max_correlation:     # Перевірка, чи модуль коефіцієнта кореляції є більшим за поточне максимальне значення.
            max_correlation = abs(correlation)     # Якщо умова вище виконується, оновлюємо max_correlation новим значенням
            feature_A, feature_B = df.columns[i], df.columns[j]  # Оновлення feature_A та feature_B іменами стовпців, які утворюють пару з максимальним або мінімальним коефіцієнтом кореляці

print(f"Найбільша кореляція (окрім 1 та 2 стовпців) між {feature_A} та {feature_B}: {max_correlation}")


# Збудовуємо relplot для цих двох ознак
sns.relplot(x=feature_A, y=feature_B, data=df)
plt.show()
# Out:
# Найбільша кореляція (окрім 1 та 2 стовпців) між radius_mean та perimeter_mean: 0.9978552814938105

# %%
# Видалення колонок з відсутніми значеннями
df_no_missing_columns = df.dropna(axis=1, how='any')

# Заповнення відсутніх значень в залишених колонках
df_no_missing_columns_filled = df_no_missing_columns.fillna(0)

# %%
# Визначення пари ознак з найбільшою кореляцією (окрім 1 та 2 стовпців)
max_correlation = 0
feature_A, feature_B = None, None

for i in range(2, len(df.columns)):                # Цикл, який перебирає індекси стовпців у фреймі даних, починаючи з індексу 2.
    for j in range(i + 1, len(df.columns)):      # Внутрішній цикл, який перебирає індекси стовпців у фреймі даних, починаючи з індексу, який є на одиницю більшим за i
        correlation = df[df.columns[i]].corr(df[df.columns[j]])  # Обчислення коефіцієнта кореляції між парою стовпців
        if abs(correlation) > max_correlation:     # Перевірка, чи модуль коефіцієнта кореляції є більшим за поточне максимальне значення.
            max_correlation = abs(correlation)     # Якщо умова вище виконується, оновлюємо max_correlation новим значенням
            feature_A, feature_B = df.columns[i], df.columns[j]  # Оновлення feature_A та feature_B іменами стовпців, які утворюють пару з максимальним або мінімальним коефіцієнтом кореляці

print(f"Найбільша кореляція (окрім 1 та 2 стовпців) між {feature_A} та {feature_B}: {max_correlation}")

# Випадкове видалення 10% значень для обох ознак з найбільшою кореляцією
df_no_missing = df.copy()

for feature in [feature_A, feature_B]:   # Це цикл, який перебирає стовпці, які були знайдені з найбільшим або найменшим коефіцієнтом
    indices_to_remove = np.random.choice(df_no_missing.index, size=int(0.1 * len(df_no_missing)), replace=False) # вказує розмір (кількість) індексів, які потрібно вибрати, і в даному випадку це 10% від усіх рядків.
    df_no_missing.loc[indices_to_remove, feature] = np.nan   # Встановлення випадково обраних рядків та стовпця feature у фреймі даних 

# Підрахунок кореляції після видалення випадкових значень
correlation_after_removal = df_no_missing[feature_A].corr(df_no_missing[feature_B])
print(f"Кореляція після видалення випадкових значень: {correlation_after_removal}")

# Збудова multipple scatterplot за допомогою FacetGrid
g = sns.FacetGrid(df_no_missing, col="diagnosis", height=4, aspect=1) # aspect=1 - на співвідношення ширини та висоти.
g.map(sns.scatterplot, feature_A, feature_B, alpha=0.7) # alpha=0.7 вказує на прозорість точок
g.add_legend()

plt.show()
# Out:
# Найбільша кореляція (окрім 1 та 2 стовпців) між radius_mean та perimeter_mean: 0.9978552814938105
# Кореляція після видалення випадкових значень: 0.9979901629165129
